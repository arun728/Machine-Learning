# %% [markdown]
# # Log in to the Subject Scheme Confluence Page

# %%
import requests
from requests import sessions, session, Session
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
def login_to_confluence():
            
#     source = requests.get(url, headers=headers)

    with requests:
        url = 'https://confluence-lvs.prod.mcafee.com/pages/viewpage.action?spaceKey=IDCS&title=Subject+scheme+tracking'
        headers = {"user-agent": 'mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/83.0.4103.116 safari/537.36'}
        source = requests.get(url, headers=headers)
        soup = BeautifulSoup(source.content, 'lxml')
        login_data = {
        'os_username' : 'akumar5',
        'os_password' : 'Decem@2020',
        'login' : 'Log in',
        'SAMLRequest': soup.find('input', attrs={'name': 'SAMLRequest'})['value']  
        }
        source = requests.post(url, data=login_data, headers=headers)

        new_source = requests.get('https://confluence-lvs.prod.mcafee.com/display/IDCS/Subject+scheme+tracking').text
        soup = BeautifulSoup(new_source, 'lxml')
        print(soup)
    
login_to_confluence()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-78dda79a74a4> in <module>
#      20         print(soup)
#      21
# ---> 22 login_to_confluence()
#
# <ipython-input-24-78dda79a74a4> in login_to_confluence()
#       3 #     source = requests.get(url, headers=headers)
#       4
# ----> 5     with requests:
#       6         url = 'https://confluence-lvs.prod.mcafee.com/pages/viewpage.action?spaceKey=IDCS&title=Subject+scheme+tracking'
#       7         headers = {"user-agent": 'mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/83.0.4103.116 safari/537.36'}
#
# AttributeError: __enter__

# %%
from atlassian import Confluence

# %%
confluence = Confluence(
    url='https://confluence-lvs.prod.mcafee.com',
    username='akumar5',
    password='Decem@2020')

# %%
confluence.get_all_pages_from_space('IDCS')
# Out:
# [{'id': '23047128',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Info Dev Content Solutions Home',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/Info+Dev+Content+Solutions+Home',
#    'edit': '/pages/resumedraft.action?draftId=23047128',
#    'tinyui': '/x/2KtfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047128'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047128/child',
#    'restrictions': '/rest/api/content/23047128/restriction/byOperation',
#    'history': '/rest/api/content/23047128/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047128/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047140',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Operations',
#   'extensions': {'position': 2},
#   '_links': {'webui': '/display/IDCS/Operations',
#    'edit': '/pages/resumedraft.action?draftId=23047140',
#    'tinyui': '/x/5KtfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047140'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047140/child',
#    'restrictions': '/rest/api/content/23047140/restriction/byOperation',
#    'history': '/rest/api/content/23047140/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047140/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047145',
#   'type': 'page',
#   'status': 'current',
#   'title': '01. Rebranding',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/01.+Rebranding',
#    'edit': '/pages/resumedraft.action?draftId=23047145',
#    'tinyui': '/x/6atfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047145'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047145/child',
#    'restrictions': '/rest/api/content/23047145/restriction/byOperation',
#    'history': '/rest/api/content/23047145/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047145/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047147',
#   'type': 'page',
#   'status': 'current',
#   'title': '02. Portal Roll-out',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/02.+Portal+Roll-out',
#    'edit': '/pages/resumedraft.action?draftId=23047147',
#    'tinyui': '/x/66tfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047147'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047147/child',
#    'restrictions': '/rest/api/content/23047147/restriction/byOperation',
#    'history': '/rest/api/content/23047147/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047147/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047180',
#   'type': 'page',
#   'status': 'current',
#   'title': '01 PRO Project Overview',
#   'extensions': {'position': 0},
#   '_links': {'webui': '/display/IDCS/01+PRO+Project+Overview',
#    'edit': '/pages/resumedraft.action?draftId=23047180',
#    'tinyui': '/x/DKxfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047180'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047180/child',
#    'restrictions': '/rest/api/content/23047180/restriction/byOperation',
#    'history': '/rest/api/content/23047180/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047180/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047182',
#   'type': 'page',
#   'status': 'current',
#   'title': '02 PRO Stakeholder List',
#   'extensions': {'position': 1},
#   '_links': {'webui': '/display/IDCS/02+PRO+Stakeholder+List',
#    'edit': '/pages/resumedraft.action?draftId=23047182',
#    'tinyui': '/x/DqxfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047182'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047182/child',
#    'restrictions': '/rest/api/content/23047182/restriction/byOperation',
#    'history': '/rest/api/content/23047182/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047182/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047185',
#   'type': 'page',
#   'status': 'current',
#   'title': 'File lists',
#   'extensions': {'position': 5},
#   '_links': {'webui': '/display/IDCS/File+lists',
#    'edit': '/pages/resumedraft.action?draftId=23047185',
#    'tinyui': '/x/EaxfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047185'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047185/child',
#    'restrictions': '/rest/api/content/23047185/restriction/byOperation',
#    'history': '/rest/api/content/23047185/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047185/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047190',
#   'type': 'page',
#   'status': 'current',
#   'title': '05 PRO Implementation',
#   'extensions': {'position': 13},
#   '_links': {'webui': '/display/IDCS/05+PRO+Implementation',
#    'edit': '/pages/resumedraft.action?draftId=23047190',
#    'tinyui': '/x/FqxfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047190'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047190/child',
#    'restrictions': '/rest/api/content/23047190/restriction/byOperation',
#    'history': '/rest/api/content/23047190/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047190/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047192',
#   'type': 'page',
#   'status': 'current',
#   'title': '05.01 PRO Strategy',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/05.01+PRO+Strategy',
#    'edit': '/pages/resumedraft.action?draftId=23047192',
#    'tinyui': '/x/GKxfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047192'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047192/child',
#    'restrictions': '/rest/api/content/23047192/restriction/byOperation',
#    'history': '/rest/api/content/23047192/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047192/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047195',
#   'type': 'page',
#   'status': 'current',
#   'title': '05.02 PRO Schedule',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/05.02+PRO+Schedule',
#    'edit': '/pages/resumedraft.action?draftId=23047195',
#    'tinyui': '/x/G6xfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047195'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047195/child',
#    'restrictions': '/rest/api/content/23047195/restriction/byOperation',
#    'history': '/rest/api/content/23047195/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047195/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047199',
#   'type': 'page',
#   'status': 'current',
#   'title': '05.03 PRO Roll-out',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/05.03+PRO+Roll-out',
#    'edit': '/pages/resumedraft.action?draftId=23047199',
#    'tinyui': '/x/H6xfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047199'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047199/child',
#    'restrictions': '/rest/api/content/23047199/restriction/byOperation',
#    'history': '/rest/api/content/23047199/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047199/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047203',
#   'type': 'page',
#   'status': 'current',
#   'title': '06 PRO Close-out',
#   'extensions': {'position': 14},
#   '_links': {'webui': '/display/IDCS/06+PRO+Close-out',
#    'edit': '/pages/resumedraft.action?draftId=23047203',
#    'tinyui': '/x/I6xfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047203'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047203/child',
#    'restrictions': '/rest/api/content/23047203/restriction/byOperation',
#    'history': '/rest/api/content/23047203/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047203/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047357',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Portal Roll-out Design Files',
#   'extensions': {'position': 0},
#   '_links': {'webui': '/display/IDCS/Portal+Roll-out+Design+Files',
#    'edit': '/pages/resumedraft.action?draftId=23047357',
#    'tinyui': '/x/vaxfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047357'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047357/child',
#    'restrictions': '/rest/api/content/23047357/restriction/byOperation',
#    'history': '/rest/api/content/23047357/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047357/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047375',
#   'type': 'page',
#   'status': 'current',
#   'title': 'PRO Lessons Learned',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/PRO+Lessons+Learned',
#    'edit': '/pages/resumedraft.action?draftId=23047375',
#    'tinyui': '/x/z6xfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047375'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047375/child',
#    'restrictions': '/rest/api/content/23047375/restriction/byOperation',
#    'history': '/rest/api/content/23047375/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047375/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048180',
#   'type': 'page',
#   'status': 'current',
#   'title': '01 REB Project Overview',
#   'extensions': {'position': 0},
#   '_links': {'webui': '/display/IDCS/01+REB+Project+Overview',
#    'edit': '/pages/resumedraft.action?draftId=23048180',
#    'tinyui': '/x/9K9fAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048180'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048180/child',
#    'restrictions': '/rest/api/content/23048180/restriction/byOperation',
#    'history': '/rest/api/content/23048180/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048180/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048182',
#   'type': 'page',
#   'status': 'current',
#   'title': '02 REB Stakeholder List',
#   'extensions': {'position': 1},
#   '_links': {'webui': '/display/IDCS/02+REB+Stakeholder+List',
#    'edit': '/pages/resumedraft.action?draftId=23048182',
#    'tinyui': '/x/9q9fAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048182'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048182/child',
#    'restrictions': '/rest/api/content/23048182/restriction/byOperation',
#    'history': '/rest/api/content/23048182/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048182/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048187',
#   'type': 'page',
#   'status': 'current',
#   'title': '03 REB Analysis and Research',
#   'extensions': {'position': 10},
#   '_links': {'webui': '/display/IDCS/03+REB+Analysis+and+Research',
#    'edit': '/pages/resumedraft.action?draftId=23048187',
#    'tinyui': '/x/_69fAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048187'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048187/child',
#    'restrictions': '/rest/api/content/23048187/restriction/byOperation',
#    'history': '/rest/api/content/23048187/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048187/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048189',
#   'type': 'page',
#   'status': 'current',
#   'title': '04 REB Design',
#   'extensions': {'position': 11},
#   '_links': {'webui': '/display/IDCS/04+REB+Design',
#    'edit': '/pages/resumedraft.action?draftId=23048189',
#    'tinyui': '/x/-a9fAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048189'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048189/child',
#    'restrictions': '/rest/api/content/23048189/restriction/byOperation',
#    'history': '/rest/api/content/23048189/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048189/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048191',
#   'type': 'page',
#   'status': 'current',
#   'title': '05 REB Implementation',
#   'extensions': {'position': 12},
#   '_links': {'webui': '/display/IDCS/05+REB+Implementation',
#    'edit': '/pages/resumedraft.action?draftId=23048191',
#    'tinyui': '/x/-69fAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048191'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048191/child',
#    'restrictions': '/rest/api/content/23048191/restriction/byOperation',
#    'history': '/rest/api/content/23048191/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048191/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048193',
#   'type': 'page',
#   'status': 'current',
#   'title': '06 REB Close-Out',
#   'extensions': {'position': 13},
#   '_links': {'webui': '/display/IDCS/06+REB+Close-Out',
#    'edit': '/pages/resumedraft.action?draftId=23048193',
#    'tinyui': '/x/AbBfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048193'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048193/child',
#    'restrictions': '/rest/api/content/23048193/restriction/byOperation',
#    'history': '/rest/api/content/23048193/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048193/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048602',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Portal Rebranding file list',
#   'extensions': {'position': 4},
#   '_links': {'webui': '/display/IDCS/Portal+Rebranding+file+list',
#    'edit': '/pages/resumedraft.action?draftId=23048602',
#    'tinyui': '/x/mrFfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048602'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048602/child',
#    'restrictions': '/rest/api/content/23048602/restriction/byOperation',
#    'history': '/rest/api/content/23048602/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048602/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048789',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Copyright',
#   'extensions': {'position': 2},
#   '_links': {'webui': '/display/IDCS/Copyright',
#    'edit': '/pages/resumedraft.action?draftId=23048789',
#    'tinyui': '/x/VbJfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048789'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048789/child',
#    'restrictions': '/rest/api/content/23048789/restriction/byOperation',
#    'history': '/rest/api/content/23048789/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048789/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048975',
#   'type': 'page',
#   'status': 'current',
#   'title': 'PDF (non-portal) rebrand spec',
#   'extensions': {'position': 6},
#   '_links': {'webui': '/display/IDCS/PDF+%28non-portal%29+rebrand+spec',
#    'edit': '/pages/resumedraft.action?draftId=23048975',
#    'tinyui': '/x/D7NfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048975'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048975/child',
#    'restrictions': '/rest/api/content/23048975/restriction/byOperation',
#    'history': '/rest/api/content/23048975/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048975/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23049119',
#   'type': 'page',
#   'status': 'current',
#   'title': 'When and how to redirect Help calls to the portal',
#   'extensions': {'position': 7},
#   '_links': {'webui': '/display/IDCS/When+and+how+to+redirect+Help+calls+to+the+portal',
#    'edit': '/pages/resumedraft.action?draftId=23049119',
#    'tinyui': '/x/n7NfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23049119'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23049119/child',
#    'restrictions': '/rest/api/content/23049119/restriction/byOperation',
#    'history': '/rest/api/content/23049119/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23049119/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23049422',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Webhelp-SS rebrand spec',
#   'extensions': {'position': 9},
#   '_links': {'webui': '/display/IDCS/Webhelp-SS+rebrand+spec',
#    'edit': '/pages/resumedraft.action?draftId=23049422',
#    'tinyui': '/x/zrRfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23049422'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23049422/child',
#    'restrictions': '/rest/api/content/23049422/restriction/byOperation',
#    'history': '/rest/api/content/23049422/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23049422/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23049856',
#   'type': 'page',
#   'status': 'current',
#   'title': 'McAfee brand resources',
#   'extensions': {'position': 3},
#   '_links': {'webui': '/display/IDCS/McAfee+brand+resources',
#    'edit': '/pages/resumedraft.action?draftId=23049856',
#    'tinyui': '/x/gLZfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23049856'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23049856/child',
#    'restrictions': '/rest/api/content/23049856/restriction/byOperation',
#    'history': '/rest/api/content/23049856/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23049856/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23050558',
#   'type': 'page',
#   'status': 'current',
#   'title': '01. July Roll-out Checklist',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/01.+July+Roll-out+Checklist',
#    'edit': '/pages/resumedraft.action?draftId=23050558',
#    'tinyui': '/x/PrlfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23050558'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23050558/child',
#    'restrictions': '/rest/api/content/23050558/restriction/byOperation',
#    'history': '/rest/api/content/23050558/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23050558/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24150142',
#   'type': 'page',
#   'status': 'current',
#   'title': 'PDF (portal) rebrand spec',
#   'extensions': {'position': 5},
#   '_links': {'webui': '/display/IDCS/PDF+%28portal%29+rebrand+spec',
#    'edit': '/pages/resumedraft.action?draftId=24150142',
#    'tinyui': '/x/foBwAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24150142'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24150142/child',
#    'restrictions': '/rest/api/content/24150142/restriction/byOperation',
#    'history': '/rest/api/content/24150142/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24150142/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24152038',
#   'type': 'page',
#   'status': 'current',
#   'title': 'PDF (non-portal) sample output',
#   'extensions': {'position': 7},
#   '_links': {'webui': '/display/IDCS/PDF+%28non-portal%29+sample+output',
#    'edit': '/pages/resumedraft.action?draftId=24152038',
#    'tinyui': '/x/5odwAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24152038'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24152038/child',
#    'restrictions': '/rest/api/content/24152038/restriction/byOperation',
#    'history': '/rest/api/content/24152038/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24152038/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24152705',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Webhelp-SS (non-portal) sample output',
#   'extensions': {'position': 8},
#   '_links': {'webui': '/display/IDCS/Webhelp-SS+%28non-portal%29+sample+output',
#    'edit': '/pages/resumedraft.action?draftId=24152705',
#    'tinyui': '/x/gYpwAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24152705'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24152705/child',
#    'restrictions': '/rest/api/content/24152705/restriction/byOperation',
#    'history': '/rest/api/content/24152705/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24152705/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24152806',
#   'type': 'page',
#   'status': 'current',
#   'title': '02. August Roll-out checklist',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/02.+August+Roll-out+checklist',
#    'edit': '/pages/resumedraft.action?draftId=24152806',
#    'tinyui': '/x/5opwAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24152806'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24152806/child',
#    'restrictions': '/rest/api/content/24152806/restriction/byOperation',
#    'history': '/rest/api/content/24152806/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24152806/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24152812',
#   'type': 'page',
#   'status': 'current',
#   'title': '03. September Roll-out checklist',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/03.+September+Roll-out+checklist',
#    'edit': '/pages/resumedraft.action?draftId=24152812',
#    'tinyui': '/x/7IpwAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24152812'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24152812/child',
#    'restrictions': '/rest/api/content/24152812/restriction/byOperation',
#    'history': '/rest/api/content/24152812/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24152812/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24156451',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Subject Scheme Tracking - OLD',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/Subject+Scheme+Tracking+-+OLD',
#    'edit': '/pages/resumedraft.action?draftId=24156451',
#    'tinyui': '/x/I5lwAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24156451'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24156451/child',
#    'restrictions': '/rest/api/content/24156451/restriction/byOperation',
#    'history': '/rest/api/content/24156451/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24156451/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24875944',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Launch Plan',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/Launch+Plan',
#    'edit': '/pages/resumedraft.action?draftId=24875944',
#    'tinyui': '/x/qJN7AQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24875944'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24875944/child',
#    'restrictions': '/rest/api/content/24875944/restriction/byOperation',
#    'history': '/rest/api/content/24875944/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24875944/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24876051',
#   'type': 'page',
#   'status': 'current',
#   'title': 'PRO Measure',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/PRO+Measure',
#    'edit': '/pages/resumedraft.action?draftId=24876051',
#    'tinyui': '/x/E5R7AQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24876051'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24876051/child',
#    'restrictions': '/rest/api/content/24876051/restriction/byOperation',
#    'history': '/rest/api/content/24876051/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24876051/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '25559770',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Why is there no context-sensitive Help linking in the portal?',
#   'extensions': {'position': 0},
#   '_links': {'webui': '/pages/viewpage.action?pageId=25559770',
#    'edit': '/pages/resumedraft.action?draftId=25559770',
#    'tinyui': '/x/2gKGAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/25559770'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/25559770/child',
#    'restrictions': '/rest/api/content/25559770/restriction/byOperation',
#    'history': '/rest/api/content/25559770/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/25559770/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '25560516',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Adding the Portal Landing page to ePO Help',
#   'extensions': {'position': 1},
#   '_links': {'webui': '/display/IDCS/Adding+the+Portal+Landing+page+to+ePO+Help',
#    'edit': '/pages/resumedraft.action?draftId=25560516',
#    'tinyui': '/x/xAWGAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/25560516'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/25560516/child',
#    'restrictions': '/rest/api/content/25560516/restriction/byOperation',
#    'history': '/rest/api/content/25560516/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/25560516/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26219136',
#   'type': 'page',
#   'status': 'current',
#   'title': 'General Internal Communication',
#   'extensions': {'position': 11},
#   '_links': {'webui': '/display/IDCS/General+Internal+Communication',
#    'edit': '/pages/resumedraft.action?draftId=26219136',
#    'tinyui': '/x/gBKQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26219136'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26219136/child',
#    'restrictions': '/rest/api/content/26219136/restriction/byOperation',
#    'history': '/rest/api/content/26219136/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26219136/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26219943',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Why do we need the Doc Portal when we already have Knowledge Center?',
#   'extensions': {'position': 1},
#   '_links': {'webui': '/pages/viewpage.action?pageId=26219943',
#    'edit': '/pages/resumedraft.action?draftId=26219943',
#    'tinyui': '/x/pxWQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26219943'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26219943/child',
#    'restrictions': '/rest/api/content/26219943/restriction/byOperation',
#    'history': '/rest/api/content/26219943/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26219943/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26219986',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Can we pass the product version to the portal, so that customers only see information for the version they’re using?',
#   'extensions': {'position': 4},
#   '_links': {'webui': '/pages/viewpage.action?pageId=26219986',
#    'edit': '/pages/resumedraft.action?draftId=26219986',
#    'tinyui': '/x/0hWQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26219986'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26219986/child',
#    'restrictions': '/rest/api/content/26219986/restriction/byOperation',
#    'history': '/rest/api/content/26219986/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26219986/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26219988',
#   'type': 'page',
#   'status': 'current',
#   'title': "Why didn't my product appear in the search results?",
#   'extensions': {'position': 3},
#   '_links': {'webui': '/pages/viewpage.action?pageId=26219988',
#    'edit': '/pages/resumedraft.action?draftId=26219988',
#    'tinyui': '/x/1BWQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26219988'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26219988/child',
#    'restrictions': '/rest/api/content/26219988/restriction/byOperation',
#    'history': '/rest/api/content/26219988/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26219988/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26219990',
#   'type': 'page',
#   'status': 'current',
#   'title': 'How do customers in air-gapped environments access product documentation?',
#   'extensions': {'position': 2},
#   '_links': {'webui': '/pages/viewpage.action?pageId=26219990',
#    'edit': '/pages/resumedraft.action?draftId=26219990',
#    'tinyui': '/x/1hWQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26219990'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26219990/child',
#    'restrictions': '/rest/api/content/26219990/restriction/byOperation',
#    'history': '/rest/api/content/26219990/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26219990/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26220309',
#   'type': 'page',
#   'status': 'current',
#   'title': 'FAQ',
#   'extensions': {'position': 3},
#   '_links': {'webui': '/display/IDCS/FAQ',
#    'edit': '/pages/resumedraft.action?draftId=26220309',
#    'tinyui': '/x/FReQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26220309'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26220309/child',
#    'restrictions': '/rest/api/content/26220309/restriction/byOperation',
#    'history': '/rest/api/content/26220309/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26220309/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26224136',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Downloads Page Design - Redirect',
#   'extensions': {'position': 1},
#   '_links': {'webui': '/display/IDCS/Downloads+Page+Design+-+Redirect',
#    'edit': '/pages/resumedraft.action?draftId=26224136',
#    'tinyui': '/x/CCaQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26224136'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26224136/child',
#    'restrictions': '/rest/api/content/26224136/restriction/byOperation',
#    'history': '/rest/api/content/26224136/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26224136/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26224692',
#   'type': 'page',
#   'status': 'current',
#   'title': 'INFO Collaborative Review',
#   'extensions': {'position': 13},
#   '_links': {'webui': '/display/IDCS/INFO+Collaborative+Review',
#    'edit': '/pages/resumedraft.action?draftId=26224692',
#    'tinyui': '/x/NCiQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26224692'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26224692/child',
#    'restrictions': '/rest/api/content/26224692/restriction/byOperation',
#    'history': '/rest/api/content/26224692/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26224692/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26225919',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Publishing to the Docs Portal - Delivery Workflow',
#   'extensions': {'position': 12},
#   '_links': {'webui': '/display/IDCS/Publishing+to+the+Docs+Portal+-+Delivery+Workflow',
#    'edit': '/pages/resumedraft.action?draftId=26225919',
#    'tinyui': '/x/-yyQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26225919'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26225919/child',
#    'restrictions': '/rest/api/content/26225919/restriction/byOperation',
#    'history': '/rest/api/content/26225919/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26225919/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26232096',
#   'type': 'page',
#   'status': 'current',
#   'title': 'How language switching works in the portal',
#   'extensions': {'position': 4},
#   '_links': {'webui': '/display/IDCS/How+language+switching+works+in+the+portal',
#    'edit': '/pages/resumedraft.action?draftId=26232096',
#    'tinyui': '/x/IEWQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26232096'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26232096/child',
#    'restrictions': '/rest/api/content/26232096/restriction/byOperation',
#    'history': '/rest/api/content/26232096/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26232096/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26233234',
#   'type': 'page',
#   'status': 'current',
#   'title': '01 CLBRVW Project Overview',
#   'extensions': {'position': 0},
#   '_links': {'webui': '/display/IDCS/01+CLBRVW+Project+Overview',
#    'edit': '/pages/resumedraft.action?draftId=26233234',
#    'tinyui': '/x/kkmQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26233234'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26233234/child',
#    'restrictions': '/rest/api/content/26233234/restriction/byOperation',
#    'history': '/rest/api/content/26233234/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26233234/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26233254',
#   'type': 'page',
#   'status': 'current',
#   'title': '02 CLBRVW Requirements',
#   'extensions': {'position': 1},
#   '_links': {'webui': '/display/IDCS/02+CLBRVW+Requirements',
#    'edit': '/pages/resumedraft.action?draftId=26233254',
#    'tinyui': '/x/pkmQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26233254'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26233254/child',
#    'restrictions': '/rest/api/content/26233254/restriction/byOperation',
#    'history': '/rest/api/content/26233254/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26233254/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26233293',
#   'type': 'page',
#   'status': 'current',
#   'title': '03 CLBRVW Analysis and Research',
#   'extensions': {'position': 2},
#   '_links': {'webui': '/display/IDCS/03+CLBRVW+Analysis+and+Research',
#    'edit': '/pages/resumedraft.action?draftId=26233293',
#    'tinyui': '/x/zUmQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26233293'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26233293/child',
#    'restrictions': '/rest/api/content/26233293/restriction/byOperation',
#    'history': '/rest/api/content/26233293/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26233293/descendant',
#    'space': '/rest/api/space/IDCS'}}]

# %%
confluence.page_exists('IDCS','Subject scheme tracking')
# Out:
# True

# %%
confluence.get_page_id('IDCS', 'Subject scheme tracking')
# Out:
# '29093395'

# %%
confluence.get_page_space('29093395')
# Out:
# 'IDCS'

# %%
confluence.get_page_by_title('IDCS', 'Subject scheme tracking', start=0, limit=100)
# Out:
# {'id': '29093395',
#  'type': 'page',
#  'status': 'current',
#  'title': 'Subject scheme tracking',
#  'extensions': {'position': 0},
#  '_links': {'webui': '/display/IDCS/Subject+scheme+tracking',
#   'edit': '/pages/resumedraft.action?draftId=29093395',
#   'tinyui': '/x/E_67AQ',
#   'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/29093395'},
#  '_expandable': {'container': '/rest/api/space/IDCS',
#   'metadata': '',
#   'operations': '',
#   'children': '/rest/api/content/29093395/child',
#   'restrictions': '/rest/api/content/29093395/restriction/byOperation',
#   'history': '/rest/api/content/29093395/history',
#   'ancestors': '',
#   'body': '',
#   'version': '',
#   'descendants': '/rest/api/content/29093395/descendant',
#   'space': '/rest/api/space/IDCS'}}

# %%
confluence.get_page_labels('29093395', prefix=None, start=None, limit=None)
# Out:
# {'results': [{'prefix': 'my', 'name': 'favourite', 'id': '87162958'}],
#  'start': 0,
#  'limit': 200,
#  'size': 1,
#  '_links': {'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/29093395/label',
#   'base': 'https://confluence-lvs.prod.mcafee.com',
#   'context': ''}}

# %%
-mjson.tool
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-08ba2bf440a4> in <module>
# ----> 1 -mjson.tool
#
# NameError: name 'mjson' is not defined

# %%
confluence.get_all_pages_from_space('IDCS', start=0, limit=100, status=None, expand=None, content_type='page')
# Out:
# [{'id': '23047128',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Info Dev Content Solutions Home',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/Info+Dev+Content+Solutions+Home',
#    'edit': '/pages/resumedraft.action?draftId=23047128',
#    'tinyui': '/x/2KtfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047128'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047128/child',
#    'restrictions': '/rest/api/content/23047128/restriction/byOperation',
#    'history': '/rest/api/content/23047128/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047128/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047140',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Operations',
#   'extensions': {'position': 2},
#   '_links': {'webui': '/display/IDCS/Operations',
#    'edit': '/pages/resumedraft.action?draftId=23047140',
#    'tinyui': '/x/5KtfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047140'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047140/child',
#    'restrictions': '/rest/api/content/23047140/restriction/byOperation',
#    'history': '/rest/api/content/23047140/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047140/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047145',
#   'type': 'page',
#   'status': 'current',
#   'title': '01. Rebranding',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/01.+Rebranding',
#    'edit': '/pages/resumedraft.action?draftId=23047145',
#    'tinyui': '/x/6atfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047145'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047145/child',
#    'restrictions': '/rest/api/content/23047145/restriction/byOperation',
#    'history': '/rest/api/content/23047145/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047145/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047147',
#   'type': 'page',
#   'status': 'current',
#   'title': '02. Portal Roll-out',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/02.+Portal+Roll-out',
#    'edit': '/pages/resumedraft.action?draftId=23047147',
#    'tinyui': '/x/66tfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047147'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047147/child',
#    'restrictions': '/rest/api/content/23047147/restriction/byOperation',
#    'history': '/rest/api/content/23047147/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047147/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047180',
#   'type': 'page',
#   'status': 'current',
#   'title': '01 PRO Project Overview',
#   'extensions': {'position': 0},
#   '_links': {'webui': '/display/IDCS/01+PRO+Project+Overview',
#    'edit': '/pages/resumedraft.action?draftId=23047180',
#    'tinyui': '/x/DKxfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047180'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047180/child',
#    'restrictions': '/rest/api/content/23047180/restriction/byOperation',
#    'history': '/rest/api/content/23047180/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047180/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047182',
#   'type': 'page',
#   'status': 'current',
#   'title': '02 PRO Stakeholder List',
#   'extensions': {'position': 1},
#   '_links': {'webui': '/display/IDCS/02+PRO+Stakeholder+List',
#    'edit': '/pages/resumedraft.action?draftId=23047182',
#    'tinyui': '/x/DqxfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047182'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047182/child',
#    'restrictions': '/rest/api/content/23047182/restriction/byOperation',
#    'history': '/rest/api/content/23047182/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047182/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047185',
#   'type': 'page',
#   'status': 'current',
#   'title': 'File lists',
#   'extensions': {'position': 5},
#   '_links': {'webui': '/display/IDCS/File+lists',
#    'edit': '/pages/resumedraft.action?draftId=23047185',
#    'tinyui': '/x/EaxfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047185'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047185/child',
#    'restrictions': '/rest/api/content/23047185/restriction/byOperation',
#    'history': '/rest/api/content/23047185/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047185/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047190',
#   'type': 'page',
#   'status': 'current',
#   'title': '05 PRO Implementation',
#   'extensions': {'position': 13},
#   '_links': {'webui': '/display/IDCS/05+PRO+Implementation',
#    'edit': '/pages/resumedraft.action?draftId=23047190',
#    'tinyui': '/x/FqxfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047190'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047190/child',
#    'restrictions': '/rest/api/content/23047190/restriction/byOperation',
#    'history': '/rest/api/content/23047190/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047190/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047192',
#   'type': 'page',
#   'status': 'current',
#   'title': '05.01 PRO Strategy',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/05.01+PRO+Strategy',
#    'edit': '/pages/resumedraft.action?draftId=23047192',
#    'tinyui': '/x/GKxfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047192'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047192/child',
#    'restrictions': '/rest/api/content/23047192/restriction/byOperation',
#    'history': '/rest/api/content/23047192/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047192/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047195',
#   'type': 'page',
#   'status': 'current',
#   'title': '05.02 PRO Schedule',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/05.02+PRO+Schedule',
#    'edit': '/pages/resumedraft.action?draftId=23047195',
#    'tinyui': '/x/G6xfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047195'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047195/child',
#    'restrictions': '/rest/api/content/23047195/restriction/byOperation',
#    'history': '/rest/api/content/23047195/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047195/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047199',
#   'type': 'page',
#   'status': 'current',
#   'title': '05.03 PRO Roll-out',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/05.03+PRO+Roll-out',
#    'edit': '/pages/resumedraft.action?draftId=23047199',
#    'tinyui': '/x/H6xfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047199'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047199/child',
#    'restrictions': '/rest/api/content/23047199/restriction/byOperation',
#    'history': '/rest/api/content/23047199/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047199/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047203',
#   'type': 'page',
#   'status': 'current',
#   'title': '06 PRO Close-out',
#   'extensions': {'position': 14},
#   '_links': {'webui': '/display/IDCS/06+PRO+Close-out',
#    'edit': '/pages/resumedraft.action?draftId=23047203',
#    'tinyui': '/x/I6xfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047203'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047203/child',
#    'restrictions': '/rest/api/content/23047203/restriction/byOperation',
#    'history': '/rest/api/content/23047203/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047203/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047357',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Portal Roll-out Design Files',
#   'extensions': {'position': 0},
#   '_links': {'webui': '/display/IDCS/Portal+Roll-out+Design+Files',
#    'edit': '/pages/resumedraft.action?draftId=23047357',
#    'tinyui': '/x/vaxfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047357'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047357/child',
#    'restrictions': '/rest/api/content/23047357/restriction/byOperation',
#    'history': '/rest/api/content/23047357/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047357/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23047375',
#   'type': 'page',
#   'status': 'current',
#   'title': 'PRO Lessons Learned',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/PRO+Lessons+Learned',
#    'edit': '/pages/resumedraft.action?draftId=23047375',
#    'tinyui': '/x/z6xfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23047375'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23047375/child',
#    'restrictions': '/rest/api/content/23047375/restriction/byOperation',
#    'history': '/rest/api/content/23047375/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23047375/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048180',
#   'type': 'page',
#   'status': 'current',
#   'title': '01 REB Project Overview',
#   'extensions': {'position': 0},
#   '_links': {'webui': '/display/IDCS/01+REB+Project+Overview',
#    'edit': '/pages/resumedraft.action?draftId=23048180',
#    'tinyui': '/x/9K9fAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048180'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048180/child',
#    'restrictions': '/rest/api/content/23048180/restriction/byOperation',
#    'history': '/rest/api/content/23048180/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048180/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048182',
#   'type': 'page',
#   'status': 'current',
#   'title': '02 REB Stakeholder List',
#   'extensions': {'position': 1},
#   '_links': {'webui': '/display/IDCS/02+REB+Stakeholder+List',
#    'edit': '/pages/resumedraft.action?draftId=23048182',
#    'tinyui': '/x/9q9fAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048182'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048182/child',
#    'restrictions': '/rest/api/content/23048182/restriction/byOperation',
#    'history': '/rest/api/content/23048182/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048182/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048187',
#   'type': 'page',
#   'status': 'current',
#   'title': '03 REB Analysis and Research',
#   'extensions': {'position': 10},
#   '_links': {'webui': '/display/IDCS/03+REB+Analysis+and+Research',
#    'edit': '/pages/resumedraft.action?draftId=23048187',
#    'tinyui': '/x/_69fAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048187'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048187/child',
#    'restrictions': '/rest/api/content/23048187/restriction/byOperation',
#    'history': '/rest/api/content/23048187/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048187/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048189',
#   'type': 'page',
#   'status': 'current',
#   'title': '04 REB Design',
#   'extensions': {'position': 11},
#   '_links': {'webui': '/display/IDCS/04+REB+Design',
#    'edit': '/pages/resumedraft.action?draftId=23048189',
#    'tinyui': '/x/-a9fAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048189'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048189/child',
#    'restrictions': '/rest/api/content/23048189/restriction/byOperation',
#    'history': '/rest/api/content/23048189/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048189/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048191',
#   'type': 'page',
#   'status': 'current',
#   'title': '05 REB Implementation',
#   'extensions': {'position': 12},
#   '_links': {'webui': '/display/IDCS/05+REB+Implementation',
#    'edit': '/pages/resumedraft.action?draftId=23048191',
#    'tinyui': '/x/-69fAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048191'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048191/child',
#    'restrictions': '/rest/api/content/23048191/restriction/byOperation',
#    'history': '/rest/api/content/23048191/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048191/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048193',
#   'type': 'page',
#   'status': 'current',
#   'title': '06 REB Close-Out',
#   'extensions': {'position': 13},
#   '_links': {'webui': '/display/IDCS/06+REB+Close-Out',
#    'edit': '/pages/resumedraft.action?draftId=23048193',
#    'tinyui': '/x/AbBfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048193'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048193/child',
#    'restrictions': '/rest/api/content/23048193/restriction/byOperation',
#    'history': '/rest/api/content/23048193/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048193/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048602',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Portal Rebranding file list',
#   'extensions': {'position': 4},
#   '_links': {'webui': '/display/IDCS/Portal+Rebranding+file+list',
#    'edit': '/pages/resumedraft.action?draftId=23048602',
#    'tinyui': '/x/mrFfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048602'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048602/child',
#    'restrictions': '/rest/api/content/23048602/restriction/byOperation',
#    'history': '/rest/api/content/23048602/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048602/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048789',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Copyright',
#   'extensions': {'position': 2},
#   '_links': {'webui': '/display/IDCS/Copyright',
#    'edit': '/pages/resumedraft.action?draftId=23048789',
#    'tinyui': '/x/VbJfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048789'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048789/child',
#    'restrictions': '/rest/api/content/23048789/restriction/byOperation',
#    'history': '/rest/api/content/23048789/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048789/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23048975',
#   'type': 'page',
#   'status': 'current',
#   'title': 'PDF (non-portal) rebrand spec',
#   'extensions': {'position': 6},
#   '_links': {'webui': '/display/IDCS/PDF+%28non-portal%29+rebrand+spec',
#    'edit': '/pages/resumedraft.action?draftId=23048975',
#    'tinyui': '/x/D7NfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23048975'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23048975/child',
#    'restrictions': '/rest/api/content/23048975/restriction/byOperation',
#    'history': '/rest/api/content/23048975/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23048975/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23049119',
#   'type': 'page',
#   'status': 'current',
#   'title': 'When and how to redirect Help calls to the portal',
#   'extensions': {'position': 7},
#   '_links': {'webui': '/display/IDCS/When+and+how+to+redirect+Help+calls+to+the+portal',
#    'edit': '/pages/resumedraft.action?draftId=23049119',
#    'tinyui': '/x/n7NfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23049119'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23049119/child',
#    'restrictions': '/rest/api/content/23049119/restriction/byOperation',
#    'history': '/rest/api/content/23049119/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23049119/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23049422',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Webhelp-SS rebrand spec',
#   'extensions': {'position': 9},
#   '_links': {'webui': '/display/IDCS/Webhelp-SS+rebrand+spec',
#    'edit': '/pages/resumedraft.action?draftId=23049422',
#    'tinyui': '/x/zrRfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23049422'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23049422/child',
#    'restrictions': '/rest/api/content/23049422/restriction/byOperation',
#    'history': '/rest/api/content/23049422/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23049422/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23049856',
#   'type': 'page',
#   'status': 'current',
#   'title': 'McAfee brand resources',
#   'extensions': {'position': 3},
#   '_links': {'webui': '/display/IDCS/McAfee+brand+resources',
#    'edit': '/pages/resumedraft.action?draftId=23049856',
#    'tinyui': '/x/gLZfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23049856'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23049856/child',
#    'restrictions': '/rest/api/content/23049856/restriction/byOperation',
#    'history': '/rest/api/content/23049856/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23049856/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '23050558',
#   'type': 'page',
#   'status': 'current',
#   'title': '01. July Roll-out Checklist',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/01.+July+Roll-out+Checklist',
#    'edit': '/pages/resumedraft.action?draftId=23050558',
#    'tinyui': '/x/PrlfAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/23050558'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/23050558/child',
#    'restrictions': '/rest/api/content/23050558/restriction/byOperation',
#    'history': '/rest/api/content/23050558/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/23050558/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24150142',
#   'type': 'page',
#   'status': 'current',
#   'title': 'PDF (portal) rebrand spec',
#   'extensions': {'position': 5},
#   '_links': {'webui': '/display/IDCS/PDF+%28portal%29+rebrand+spec',
#    'edit': '/pages/resumedraft.action?draftId=24150142',
#    'tinyui': '/x/foBwAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24150142'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24150142/child',
#    'restrictions': '/rest/api/content/24150142/restriction/byOperation',
#    'history': '/rest/api/content/24150142/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24150142/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24152038',
#   'type': 'page',
#   'status': 'current',
#   'title': 'PDF (non-portal) sample output',
#   'extensions': {'position': 7},
#   '_links': {'webui': '/display/IDCS/PDF+%28non-portal%29+sample+output',
#    'edit': '/pages/resumedraft.action?draftId=24152038',
#    'tinyui': '/x/5odwAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24152038'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24152038/child',
#    'restrictions': '/rest/api/content/24152038/restriction/byOperation',
#    'history': '/rest/api/content/24152038/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24152038/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24152705',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Webhelp-SS (non-portal) sample output',
#   'extensions': {'position': 8},
#   '_links': {'webui': '/display/IDCS/Webhelp-SS+%28non-portal%29+sample+output',
#    'edit': '/pages/resumedraft.action?draftId=24152705',
#    'tinyui': '/x/gYpwAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24152705'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24152705/child',
#    'restrictions': '/rest/api/content/24152705/restriction/byOperation',
#    'history': '/rest/api/content/24152705/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24152705/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24152806',
#   'type': 'page',
#   'status': 'current',
#   'title': '02. August Roll-out checklist',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/02.+August+Roll-out+checklist',
#    'edit': '/pages/resumedraft.action?draftId=24152806',
#    'tinyui': '/x/5opwAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24152806'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24152806/child',
#    'restrictions': '/rest/api/content/24152806/restriction/byOperation',
#    'history': '/rest/api/content/24152806/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24152806/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24152812',
#   'type': 'page',
#   'status': 'current',
#   'title': '03. September Roll-out checklist',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/03.+September+Roll-out+checklist',
#    'edit': '/pages/resumedraft.action?draftId=24152812',
#    'tinyui': '/x/7IpwAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24152812'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24152812/child',
#    'restrictions': '/rest/api/content/24152812/restriction/byOperation',
#    'history': '/rest/api/content/24152812/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24152812/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24156451',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Subject Scheme Tracking - OLD',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/Subject+Scheme+Tracking+-+OLD',
#    'edit': '/pages/resumedraft.action?draftId=24156451',
#    'tinyui': '/x/I5lwAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24156451'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24156451/child',
#    'restrictions': '/rest/api/content/24156451/restriction/byOperation',
#    'history': '/rest/api/content/24156451/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24156451/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24875944',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Launch Plan',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/Launch+Plan',
#    'edit': '/pages/resumedraft.action?draftId=24875944',
#    'tinyui': '/x/qJN7AQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24875944'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24875944/child',
#    'restrictions': '/rest/api/content/24875944/restriction/byOperation',
#    'history': '/rest/api/content/24875944/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24875944/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '24876051',
#   'type': 'page',
#   'status': 'current',
#   'title': 'PRO Measure',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/PRO+Measure',
#    'edit': '/pages/resumedraft.action?draftId=24876051',
#    'tinyui': '/x/E5R7AQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/24876051'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/24876051/child',
#    'restrictions': '/rest/api/content/24876051/restriction/byOperation',
#    'history': '/rest/api/content/24876051/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/24876051/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '25559770',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Why is there no context-sensitive Help linking in the portal?',
#   'extensions': {'position': 0},
#   '_links': {'webui': '/pages/viewpage.action?pageId=25559770',
#    'edit': '/pages/resumedraft.action?draftId=25559770',
#    'tinyui': '/x/2gKGAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/25559770'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/25559770/child',
#    'restrictions': '/rest/api/content/25559770/restriction/byOperation',
#    'history': '/rest/api/content/25559770/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/25559770/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '25560516',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Adding the Portal Landing page to ePO Help',
#   'extensions': {'position': 1},
#   '_links': {'webui': '/display/IDCS/Adding+the+Portal+Landing+page+to+ePO+Help',
#    'edit': '/pages/resumedraft.action?draftId=25560516',
#    'tinyui': '/x/xAWGAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/25560516'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/25560516/child',
#    'restrictions': '/rest/api/content/25560516/restriction/byOperation',
#    'history': '/rest/api/content/25560516/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/25560516/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26219136',
#   'type': 'page',
#   'status': 'current',
#   'title': 'General Internal Communication',
#   'extensions': {'position': 11},
#   '_links': {'webui': '/display/IDCS/General+Internal+Communication',
#    'edit': '/pages/resumedraft.action?draftId=26219136',
#    'tinyui': '/x/gBKQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26219136'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26219136/child',
#    'restrictions': '/rest/api/content/26219136/restriction/byOperation',
#    'history': '/rest/api/content/26219136/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26219136/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26219943',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Why do we need the Doc Portal when we already have Knowledge Center?',
#   'extensions': {'position': 1},
#   '_links': {'webui': '/pages/viewpage.action?pageId=26219943',
#    'edit': '/pages/resumedraft.action?draftId=26219943',
#    'tinyui': '/x/pxWQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26219943'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26219943/child',
#    'restrictions': '/rest/api/content/26219943/restriction/byOperation',
#    'history': '/rest/api/content/26219943/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26219943/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26219986',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Can we pass the product version to the portal, so that customers only see information for the version they’re using?',
#   'extensions': {'position': 4},
#   '_links': {'webui': '/pages/viewpage.action?pageId=26219986',
#    'edit': '/pages/resumedraft.action?draftId=26219986',
#    'tinyui': '/x/0hWQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26219986'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26219986/child',
#    'restrictions': '/rest/api/content/26219986/restriction/byOperation',
#    'history': '/rest/api/content/26219986/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26219986/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26219988',
#   'type': 'page',
#   'status': 'current',
#   'title': "Why didn't my product appear in the search results?",
#   'extensions': {'position': 3},
#   '_links': {'webui': '/pages/viewpage.action?pageId=26219988',
#    'edit': '/pages/resumedraft.action?draftId=26219988',
#    'tinyui': '/x/1BWQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26219988'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26219988/child',
#    'restrictions': '/rest/api/content/26219988/restriction/byOperation',
#    'history': '/rest/api/content/26219988/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26219988/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26219990',
#   'type': 'page',
#   'status': 'current',
#   'title': 'How do customers in air-gapped environments access product documentation?',
#   'extensions': {'position': 2},
#   '_links': {'webui': '/pages/viewpage.action?pageId=26219990',
#    'edit': '/pages/resumedraft.action?draftId=26219990',
#    'tinyui': '/x/1hWQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26219990'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26219990/child',
#    'restrictions': '/rest/api/content/26219990/restriction/byOperation',
#    'history': '/rest/api/content/26219990/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26219990/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26220309',
#   'type': 'page',
#   'status': 'current',
#   'title': 'FAQ',
#   'extensions': {'position': 3},
#   '_links': {'webui': '/display/IDCS/FAQ',
#    'edit': '/pages/resumedraft.action?draftId=26220309',
#    'tinyui': '/x/FReQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26220309'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26220309/child',
#    'restrictions': '/rest/api/content/26220309/restriction/byOperation',
#    'history': '/rest/api/content/26220309/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26220309/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26224136',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Downloads Page Design - Redirect',
#   'extensions': {'position': 1},
#   '_links': {'webui': '/display/IDCS/Downloads+Page+Design+-+Redirect',
#    'edit': '/pages/resumedraft.action?draftId=26224136',
#    'tinyui': '/x/CCaQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26224136'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26224136/child',
#    'restrictions': '/rest/api/content/26224136/restriction/byOperation',
#    'history': '/rest/api/content/26224136/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26224136/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26224692',
#   'type': 'page',
#   'status': 'current',
#   'title': 'INFO Collaborative Review',
#   'extensions': {'position': 13},
#   '_links': {'webui': '/display/IDCS/INFO+Collaborative+Review',
#    'edit': '/pages/resumedraft.action?draftId=26224692',
#    'tinyui': '/x/NCiQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26224692'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26224692/child',
#    'restrictions': '/rest/api/content/26224692/restriction/byOperation',
#    'history': '/rest/api/content/26224692/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26224692/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26225919',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Publishing to the Docs Portal - Delivery Workflow',
#   'extensions': {'position': 12},
#   '_links': {'webui': '/display/IDCS/Publishing+to+the+Docs+Portal+-+Delivery+Workflow',
#    'edit': '/pages/resumedraft.action?draftId=26225919',
#    'tinyui': '/x/-yyQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26225919'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26225919/child',
#    'restrictions': '/rest/api/content/26225919/restriction/byOperation',
#    'history': '/rest/api/content/26225919/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26225919/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26232096',
#   'type': 'page',
#   'status': 'current',
#   'title': 'How language switching works in the portal',
#   'extensions': {'position': 4},
#   '_links': {'webui': '/display/IDCS/How+language+switching+works+in+the+portal',
#    'edit': '/pages/resumedraft.action?draftId=26232096',
#    'tinyui': '/x/IEWQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26232096'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26232096/child',
#    'restrictions': '/rest/api/content/26232096/restriction/byOperation',
#    'history': '/rest/api/content/26232096/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26232096/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26233234',
#   'type': 'page',
#   'status': 'current',
#   'title': '01 CLBRVW Project Overview',
#   'extensions': {'position': 0},
#   '_links': {'webui': '/display/IDCS/01+CLBRVW+Project+Overview',
#    'edit': '/pages/resumedraft.action?draftId=26233234',
#    'tinyui': '/x/kkmQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26233234'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26233234/child',
#    'restrictions': '/rest/api/content/26233234/restriction/byOperation',
#    'history': '/rest/api/content/26233234/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26233234/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26233254',
#   'type': 'page',
#   'status': 'current',
#   'title': '02 CLBRVW Requirements',
#   'extensions': {'position': 1},
#   '_links': {'webui': '/display/IDCS/02+CLBRVW+Requirements',
#    'edit': '/pages/resumedraft.action?draftId=26233254',
#    'tinyui': '/x/pkmQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26233254'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26233254/child',
#    'restrictions': '/rest/api/content/26233254/restriction/byOperation',
#    'history': '/rest/api/content/26233254/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26233254/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26233293',
#   'type': 'page',
#   'status': 'current',
#   'title': '03 CLBRVW Analysis and Research',
#   'extensions': {'position': 2},
#   '_links': {'webui': '/display/IDCS/03+CLBRVW+Analysis+and+Research',
#    'edit': '/pages/resumedraft.action?draftId=26233293',
#    'tinyui': '/x/zUmQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26233293'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26233293/child',
#    'restrictions': '/rest/api/content/26233293/restriction/byOperation',
#    'history': '/rest/api/content/26233293/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26233293/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26234028',
#   'type': 'page',
#   'status': 'current',
#   'title': 'How does the portal handle content in different locales?',
#   'extensions': {'position': 5},
#   '_links': {'webui': '/pages/viewpage.action?pageId=26234028',
#    'edit': '/pages/resumedraft.action?draftId=26234028',
#    'tinyui': '/x/rEyQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26234028'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26234028/child',
#    'restrictions': '/rest/api/content/26234028/restriction/byOperation',
#    'history': '/rest/api/content/26234028/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26234028/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26234043',
#   'type': 'page',
#   'status': 'current',
#   'title': 'How do I switch between testing on the Staging and Production site?',
#   'extensions': {'position': 6},
#   '_links': {'webui': '/pages/viewpage.action?pageId=26234043',
#    'edit': '/pages/resumedraft.action?draftId=26234043',
#    'tinyui': '/x/u0yQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26234043'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26234043/child',
#    'restrictions': '/rest/api/content/26234043/restriction/byOperation',
#    'history': '/rest/api/content/26234043/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26234043/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26236984',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Providing Product Documents in the Support Portal - Redirect',
#   'extensions': {'position': 1},
#   '_links': {'webui': '/display/IDCS/Providing+Product+Documents+in+the+Support+Portal+-+Redirect',
#    'edit': '/pages/resumedraft.action?draftId=26236984',
#    'tinyui': '/x/OFiQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26236984'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26236984/child',
#    'restrictions': '/rest/api/content/26236984/restriction/byOperation',
#    'history': '/rest/api/content/26236984/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26236984/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26237699',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Requirements for Linking to Docs Portal from Downloads - Redirect',
#   'extensions': {'position': 0},
#   '_links': {'webui': '/display/IDCS/Requirements+for+Linking+to+Docs+Portal+from+Downloads+-+Redirect',
#    'edit': '/pages/resumedraft.action?draftId=26237699',
#    'tinyui': '/x/A1uQAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26237699'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26237699/child',
#    'restrictions': '/rest/api/content/26237699/restriction/byOperation',
#    'history': '/rest/api/content/26237699/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26237699/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26238527',
#   'type': 'page',
#   'status': 'current',
#   'title': '05. November Roll-out checklist',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/05.+November+Roll-out+checklist',
#    'edit': '/pages/resumedraft.action?draftId=26238527',
#    'tinyui': '/x/P16QAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26238527'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26238527/child',
#    'restrictions': '/rest/api/content/26238527/restriction/byOperation',
#    'history': '/rest/api/content/26238527/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26238527/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26238531',
#   'type': 'page',
#   'status': 'current',
#   'title': '04. October Roll-out Checklist',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/04.+October+Roll-out+Checklist',
#    'edit': '/pages/resumedraft.action?draftId=26238531',
#    'tinyui': '/x/Q16QAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26238531'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26238531/child',
#    'restrictions': '/rest/api/content/26238531/restriction/byOperation',
#    'history': '/rest/api/content/26238531/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26238531/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '26238751',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Schema Update Process (Proposed)',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/pages/viewpage.action?pageId=26238751',
#    'edit': '/pages/resumedraft.action?draftId=26238751',
#    'tinyui': '/x/H1_QAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/26238751'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/26238751/child',
#    'restrictions': '/rest/api/content/26238751/restriction/byOperation',
#    'history': '/rest/api/content/26238751/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/26238751/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '27004425',
#   'type': 'page',
#   'status': 'current',
#   'title': 'How users will find product help documentation in the Cloud',
#   'extensions': {'position': 7},
#   '_links': {'webui': '/display/IDCS/How+users+will+find+product+help+documentation+in+the+Cloud',
#    'edit': '/pages/resumedraft.action?draftId=27004425',
#    'tinyui': '/x/CQ6cAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/27004425'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/27004425/child',
#    'restrictions': '/rest/api/content/27004425/restriction/byOperation',
#    'history': '/rest/api/content/27004425/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/27004425/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '27009557',
#   'type': 'page',
#   'status': 'current',
#   'title': '04 PRO Design',
#   'extensions': {'position': 3},
#   '_links': {'webui': '/display/IDCS/04+PRO+Design',
#    'edit': '/pages/resumedraft.action?draftId=27009557',
#    'tinyui': '/x/FSKcAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/27009557'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/27009557/child',
#    'restrictions': '/rest/api/content/27009557/restriction/byOperation',
#    'history': '/rest/api/content/27009557/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/27009557/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '27009568',
#   'type': 'page',
#   'status': 'current',
#   'title': '03 PRO Analysis and Research',
#   'extensions': {'position': 2},
#   '_links': {'webui': '/display/IDCS/03+PRO+Analysis+and+Research',
#    'edit': '/pages/resumedraft.action?draftId=27009568',
#    'tinyui': '/x/ICKcAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/27009568'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/27009568/child',
#    'restrictions': '/rest/api/content/27009568/restriction/byOperation',
#    'history': '/rest/api/content/27009568/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/27009568/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '27009597',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Downloads Page Integration - Redirect',
#   'extensions': {'position': 8},
#   '_links': {'webui': '/display/IDCS/Downloads+Page+Integration+-+Redirect',
#    'edit': '/pages/resumedraft.action?draftId=27009597',
#    'tinyui': '/x/PSKcAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/27009597'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
# ...
#  {'id': '29093395',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Subject scheme tracking',
#   'extensions': {'position': 0},
#   '_links': {'webui': '/display/IDCS/Subject+scheme+tracking',
#    'edit': '/pages/resumedraft.action?draftId=29093395',
#    'tinyui': '/x/E_67AQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/29093395'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/29093395/child',
#    'restrictions': '/rest/api/content/29093395/restriction/byOperation',
#    'history': '/rest/api/content/29093395/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/29093395/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '29925059',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Publishing to Production',
#   'extensions': {'position': 4},
#   '_links': {'webui': '/display/IDCS/Publishing+to+Production',
#    'edit': '/pages/resumedraft.action?draftId=29925059',
#    'tinyui': '/x/w57IAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/29925059'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/29925059/child',
#    'restrictions': '/rest/api/content/29925059/restriction/byOperation',
#    'history': '/rest/api/content/29925059/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/29925059/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '29925111',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Sprint Reviews and Meeting Notes',
#   'extensions': {'position': 4},
#   '_links': {'webui': '/display/IDCS/Sprint+Reviews+and+Meeting+Notes',
#    'edit': '/pages/resumedraft.action?draftId=29925111',
#    'tinyui': '/x/957IAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/29925111'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/29925111/child',
#    'restrictions': '/rest/api/content/29925111/restriction/byOperation',
#    'history': '/rest/api/content/29925111/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/29925111/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '29925112',
#   'type': 'page',
#   'status': 'current',
#   'title': '2017-12-01 Meeting notes',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/2017-12-01+Meeting+notes',
#    'edit': '/pages/resumedraft.action?draftId=29925112',
#    'tinyui': '/x/_J7IAQ',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/29925112'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/29925112/child',
#    'restrictions': '/rest/api/content/29925112/restriction/byOperation',
#    'history': '/rest/api/content/29925112/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/29925112/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '33806410',
#   'type': 'page',
#   'status': 'current',
#   'title': '2018-02-15 Sprint 16 Review',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/2018-02-15+Sprint+16+Review',
#    'edit': '/pages/resumedraft.action?draftId=33806410',
#    'tinyui': '/x/StgDAg',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/33806410'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/33806410/child',
#    'restrictions': '/rest/api/content/33806410/restriction/byOperation',
#    'history': '/rest/api/content/33806410/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/33806410/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '33812575',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Content Solutions Space Rolodex',
#   'extensions': {'position': 6},
#   '_links': {'webui': '/display/IDCS/Content+Solutions+Space+Rolodex',
#    'edit': '/pages/resumedraft.action?draftId=33812575',
#    'tinyui': '/x/X-ADAg',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/33812575'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/33812575/child',
#    'restrictions': '/rest/api/content/33812575/restriction/byOperation',
#    'history': '/rest/api/content/33812575/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/33812575/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '36082224',
#   'type': 'page',
#   'status': 'current',
#   'title': '2018-03-01 Sprint 17 Review',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/2018-03-01+Sprint+17+Review',
#    'edit': '/pages/resumedraft.action?draftId=36082224',
#    'tinyui': '/x/MJImAg',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/36082224'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/36082224/child',
#    'restrictions': '/rest/api/content/36082224/restriction/byOperation',
#    'history': '/rest/api/content/36082224/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/36082224/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '36083943',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Doc Plan and Schedules Enhancement Tracking',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/Doc+Plan+and+Schedules+Enhancement+Tracking',
#    'edit': '/pages/resumedraft.action?draftId=36083943',
#    'tinyui': '/x/55gmAg',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/36083943'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/36083943/child',
#    'restrictions': '/rest/api/content/36083943/restriction/byOperation',
#    'history': '/rest/api/content/36083943/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/36083943/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '36090948',
#   'type': 'page',
#   'status': 'current',
#   'title': 'MCP 2018-03-07 Meeting notes',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/MCP+2018-03-07+Meeting+notes',
#    'edit': '/pages/resumedraft.action?draftId=36090948',
#    'tinyui': '/x/RLQmAg',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/36090948'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/36090948/child',
#    'restrictions': '/rest/api/content/36090948/restriction/byOperation',
#    'history': '/rest/api/content/36090948/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/36090948/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '37292148',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Vendor Management - Zoomin Docs',
#   'extensions': {'position': 5},
#   '_links': {'webui': '/display/IDCS/Vendor+Management+-+Zoomin+Docs',
#    'edit': '/pages/resumedraft.action?draftId=37292148',
#    'tinyui': '/x/dAg5Ag',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/37292148'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/37292148/child',
#    'restrictions': '/rest/api/content/37292148/restriction/byOperation',
#    'history': '/rest/api/content/37292148/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/37292148/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '37296617',
#   'type': 'page',
#   'status': 'current',
#   'title': '2018-03-15 Sprint 18 notes',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/2018-03-15+Sprint+18+notes',
#    'edit': '/pages/resumedraft.action?draftId=37296617',
#    'tinyui': '/x/6Rk5Ag',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/37296617'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/37296617/child',
#    'restrictions': '/rest/api/content/37296617/restriction/byOperation',
#    'history': '/rest/api/content/37296617/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/37296617/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '37316276',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Decision log',
#   'extensions': {'position': 8},
#   '_links': {'webui': '/display/IDCS/Decision+log',
#    'edit': '/pages/resumedraft.action?draftId=37316276',
#    'tinyui': '/x/tGY5Ag',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/37316276'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/37316276/child',
#    'restrictions': '/rest/api/content/37316276/restriction/byOperation',
#    'history': '/rest/api/content/37316276/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/37316276/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '39747263',
#   'type': 'page',
#   'status': 'current',
#   'title': '2018-05-03 Meeting notes',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/2018-05-03+Meeting+notes',
#    'edit': '/pages/resumedraft.action?draftId=39747263',
#    'tinyui': '/x/v35eAg',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/39747263'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/39747263/child',
#    'restrictions': '/rest/api/content/39747263/restriction/byOperation',
#    'history': '/rest/api/content/39747263/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/39747263/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '41432645',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Interop Reference Config Docs 2018-05-21',
#   'extensions': {'position': 9},
#   '_links': {'webui': '/display/IDCS/Interop+Reference+Config+Docs+2018-05-21',
#    'edit': '/pages/resumedraft.action?draftId=41432645',
#    'tinyui': '/x/RTZ4Ag',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/41432645'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/41432645/child',
#    'restrictions': '/rest/api/content/41432645/restriction/byOperation',
#    'history': '/rest/api/content/41432645/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/41432645/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '43556933',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Top 9 issues with McAfee InfoDev tools',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/Top+9+issues+with+McAfee+InfoDev+tools',
#    'edit': '/pages/resumedraft.action?draftId=43556933',
#    'tinyui': '/x/RaCYAg',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/43556933'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/43556933/child',
#    'restrictions': '/rest/api/content/43556933/restriction/byOperation',
#    'history': '/rest/api/content/43556933/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/43556933/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '43579833',
#   'type': 'page',
#   'status': 'current',
#   'title': '2018-06-28 Content Solutions Sprint Review/Status Update',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/pages/viewpage.action?pageId=43579833',
#    'edit': '/pages/resumedraft.action?draftId=43579833',
#    'tinyui': '/x/ufmYAg',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/43579833'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/43579833/child',
#    'restrictions': '/rest/api/content/43579833/restriction/byOperation',
#    'history': '/rest/api/content/43579833/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/43579833/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '44931349',
#   'type': 'page',
#   'status': 'current',
#   'title': "RFP: Replacing McAfee InfoDev's technical documentation portal",
#   'extensions': {'position': 10},
#   '_links': {'webui': '/display/IDCS/RFP%3A+Replacing+McAfee+InfoDev%27s+technical+documentation+portal',
#    'edit': '/pages/resumedraft.action?draftId=44931349',
#    'tinyui': '/x/FZmtAg',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/44931349'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/44931349/child',
#    'restrictions': '/rest/api/content/44931349/restriction/byOperation',
#    'history': '/rest/api/content/44931349/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/44931349/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '44938362',
#   'type': 'page',
#   'status': 'current',
#   'title': '2018-07-11 Retrospective',
#   'extensions': {'position': 11},
#   '_links': {'webui': '/display/IDCS/2018-07-11+Retrospective',
#    'edit': '/pages/resumedraft.action?draftId=44938362',
#    'tinyui': '/x/erStAg',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/44938362'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/44938362/child',
#    'restrictions': '/rest/api/content/44938362/restriction/byOperation',
#    'history': '/rest/api/content/44938362/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/44938362/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '46499244',
#   'type': 'page',
#   'status': 'current',
#   'title': '2018-07-26 Content Solutions Sprint Review and Meeting Notes',
#   'extensions': {'position': 'none'},
#   '_links': {'webui': '/display/IDCS/2018-07-26+Content+Solutions+Sprint+Review+and+Meeting+Notes',
#    'edit': '/pages/resumedraft.action?draftId=46499244',
#    'tinyui': '/x/rIXFAg',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/46499244'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/46499244/child',
#    'restrictions': '/rest/api/content/46499244/restriction/byOperation',
#    'history': '/rest/api/content/46499244/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/46499244/descendant',
#    'space': '/rest/api/space/IDCS'}},
#  {'id': '47702984',
#   'type': 'page',
#   'status': 'current',
#   'title': 'Tips and troubleshooting',
#   'extensions': {'position': 5},
#   '_links': {'webui': '/display/IDCS/Tips+and+troubleshooting',
#    'edit': '/pages/resumedraft.action?draftId=47702984',
#    'tinyui': '/x/yOPXAg',
#    'self': 'https://confluence-lvs.prod.mcafee.com/rest/api/content/47702984'},
#   '_expandable': {'container': '/rest/api/space/IDCS',
#    'metadata': '',
#    'operations': '',
#    'children': '/rest/api/content/47702984/child',
#    'restrictions': '/rest/api/content/47702984/restriction/byOperation',
#    'history': '/rest/api/content/47702984/history',
#    'ancestors': '',
#    'body': '',
#    'version': '',
#    'descendants': '/rest/api/content/47702984/descendant',
#    'space': '/rest/api/space/IDCS'}}]

# %% [markdown]
# # Splitting the Product Names and Product Keys into Separate Lists

# %%
rows = []

table = soup.find("table")

table_rows = table.find_all('tr')

for tr in table_rows:
    td = tr.find_all('td')
    for item in td:
        row = item.text
        rows.append(row)

# %%
product_names = []
product_keys = []

table = soup.find("table")

table_rows = table.find_all('tr')

for tr in table_rows:
    td = tr.find_all('td')
    row = [item.text for item in td]
    col1 = row[0:1]
    col2 = row[1:2]
    
    col1 = ''.join(col1)
    col2 = ''.join(col2)
    
    product_names.append(col1)
    product_keys.append(col2)

# %%
prod_dict = dict(zip(product_keys, product_names))

# %% [markdown]
# # Building the XML document

# %%
import xml.etree.ElementTree as ET
from xml.dom import minidom

# %%
# subjectdef1 = ET.SubElement(subjectHead, "subjectdef", keys=k, navtitle=v)
# subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
# subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
# subjectdef4 = ET.SubElement(subjectdef3, "subjectdef", keys=k, navtitle=v)

# %%
root = ET.Element("subjectScheme")
subjectHead = ET.SubElement(root, "subjectHead", navtitle='Product', id='product-head')
subjectHead2 = ET.SubElement(root, "subjectHead", navtitle='Category', id='cat-head')
subjectHead3 = ET.SubElement(root, "subjectHead", navtitle='Landing', id='landing-head', outputclass='landing')

# Product facets
for k,v in prod_dict.items():
      
    if re.findall(r'\D{5,}', v) and 'Cloud Threat Detection' not in v and 'Endpoint Protection for Mac' not in v and 'Device Control' not in v and 'System Information Reporter' not in v and 'Saas Web Protection Service' not in v and 'SAAS-WPS' not in v and 'Security as a Service' not in v:
        # MACC
        if re.findall(r'Application and Change Control', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^MACC \d.\d.\D', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'Application Control$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^Change Control', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        # DLP
        elif re.findall(r'^MVISION$', v): 
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'On-premises', v): 
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'MV-DLPE|MV-DLPMac|MV-DLPD|MV-DLPP|MV-DLPM', v): 
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'DLPE \d\d.\d.\D', v): 
            subjectdef4 = ET.SubElement(subjectdef3, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'DLPMac \d\d.\d.\D', v): 
            subjectdef4 = ET.SubElement(subjectdef3, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'DLPD \d\d.\d.\D', v): 
            subjectdef4 = ET.SubElement(subjectdef3, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'DLPP \d\d.\d.\D', v): 
            subjectdef4 = ET.SubElement(subjectdef3, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'DLPM \d\d.\d.\D', v):
            subjectdef4 = ET.SubElement(subjectdef3, "subjectdef", keys=k, navtitle=v)
        # ENS
        elif re.findall(r'ENSS \d.\d.\d', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'ENS-\D{2,} \d\d.\d.\D', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'ENS-\D{2,} \d\d.\d.\d', v):
            subjectdef4 = ET.SubElement(subjectdef3, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'ENS-\D{2,} \d\d.\d.\d', v):
            subjectdef4 = ET.SubElement(subjectdef3, "subjectdef", keys=k, navtitle=v)
        # MEPM, ENSS, ePO-CB    
        elif re.findall(r'MEPM \d.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'ENSS \d.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'EPO-CB \d.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'EPO-CB \d.\d.\d', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'HIPS \d.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'HIPS \d.\d.\d{1,}', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^MV-MNE$', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'MOVE \d.\d{1,}.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'MOVE \d.\d{1,}.\d', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^MV-CB$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^MV-EPT$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^MV-EDR$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^MV-EPO$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^MV-INS$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^MV-UCE$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^SAAS-EMA$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^SAAS-EMP$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'SAAS-OM \d.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'SAAS-OM \d.\d.\d', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'NTBA \d.\d.\d', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'MSDW \d.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'MSDW \d.\d.\d', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'MSME \d.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'MSME \d.\d.\d', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'MSMS \d.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^MV-TIE$', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'VNSP \d{1,}.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'VNSP \d{1,}.\d.\d', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'VSEL \d{1,}.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'VSEL \d{1,}.\d.\d', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'VSES \d{1,}.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'VSE-CLS \d{1,}.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'VSEM \d{1,}.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'MVM-D \d{1,}.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'MVM-D \d{1,}.\d.\d', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^WGCS-UCE$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^EPO-CLD$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
        else:
            subjectdef1 = ET.SubElement(subjectHead, "subjectdef", keys=k, navtitle=v)
             
    # DLP
    elif re.findall(r'DLP \d\d.\d.\D', v):
        subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
    # ENS
    elif re.findall(r'ENS \d\d.\d.\D', v):
        subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
    # ENS    
    elif re.findall(r'ENS \d\d.\d.\d{1,}', v):
        subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
    elif re.findall(r'ESM \d\d.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
    elif re.findall(r'ESM \d\d.\d.\d', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
    elif re.findall(r'EPO-CLD', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
    elif re.findall(r'^INV$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
    elif re.findall(r'^MV-M$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
    elif re.findall(r'NSP \d\d.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
    elif re.findall(r'NSP \d\d.\d.\d', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
    elif re.findall(r'MWG \d\d.\d.\D', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
    elif re.findall(r'^PBC$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
    elif re.findall(r'^WGCS$', v):
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)
            
    
    elif re.findall(r'\D{2,} \d.\d.\D', v):
        
        if re.findall(r'^AC \d.\d.\D', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^CC \d.\d.\D', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'EPO \d.\d\d.\d', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'MNE \d.\d.\D', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'TIE \d.\d.\D', v):
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)
        else:
            subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)

    elif re.findall(r'\D{2,} \d.\d.\d', v):
        
        if re.findall(r'^AC \d.\d.\d', v):
            subjectdef4 = ET.SubElement(subjectdef3, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'^CC \d.\d.\d', v):
            subjectdef4 = ET.SubElement(subjectdef3, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'MNE \d.\d.\d', v):
            subjectdef4 = ET.SubElement(subjectdef3, "subjectdef", keys=k, navtitle=v)
        elif re.findall(r'TIE \d.\d.\d', v):
            subjectdef4 = ET.SubElement(subjectdef3, "subjectdef", keys=k, navtitle=v)
        else:
            subjectdef3 = ET.SubElement(subjectdef2, "subjectdef", keys=k, navtitle=v)

# Categorical facets
cat_dict = {'cat-hardware':'Hardware', 'cat-installation':'Installation and Getting Started',
            'cat-integration':'Integration', 'cat-migration':'Migration', 
           'cat-product':'Product Usage', 'cat-reference':'Reference', 
           'cat-release-notes':'Release-Notes'}
for k,v in cat_dict.items():
    subjectdef1 = ET.SubElement(subjectHead2, "subjectdef", keys=k, navtitle=v)

# Landing facets
land_dict = {'land-endpoint-security-v10-7-x':'ENS 10.7.x', 'land-endpoint-security-v10-6-x':'ENS 10.6.x',
            'land-endpoint-security-v10-6-0':'ENS 10.6.0', 'land-endpoint-security-v10-5-x':'ENS 10.5.x', 
           'land-endpoint-security-v10-5-0':'ENS 10.5.0', 'land-epo-v5-10-x':'EPO 5.10.x', 
           'land-epo-v5-9-x':'EPO 5.9.x'}
for k,v in land_dict.items():
    if re.findall(r'\D{3,} \d{1,}.\d{1,}.\D', v):
        subjectdef1 = ET.SubElement(subjectHead3, "subjectdef", keys=k, navtitle=v)
        
    else:
        subjectdef2 = ET.SubElement(subjectdef1, "subjectdef", keys=k, navtitle=v)


xmlstr = minidom.parseString(ET.tostring(root)).toprettyxml(indent="   ")
with open("automated_subject_scheme.ditamap", "w") as f:
    f.write(xmlstr)

# %%
with open('header_schema.ditamap') as f:
    schema = f.readlines()
    
with open('test-subject-scheme.ditamap', 'w') as f:
    contents = f.writelines(schema)
    
with open('automated_subject_scheme.ditamap') as f:
    f.seek(24)
    subject_scheme = f.readlines()
    
with open('test-subject-scheme.ditamap', 'a+') as f:
    final = f.writelines(subject_scheme)
