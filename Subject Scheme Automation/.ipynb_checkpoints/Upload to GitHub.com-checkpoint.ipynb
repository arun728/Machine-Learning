# %%
from github import Github
import os
from pprint import pprint
import shutil

# %%
g = Github(login_or_token='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')

# %%
for u in g.get_repos():
    print(u)
# Out:
# Repository(full_name="mojombo/grit")
# Repository(full_name="wycats/merb-core")
# Repository(full_name="rubinius/rubinius")
# Repository(full_name="mojombo/god")
# Repository(full_name="vanpelt/jsawesome")
# Repository(full_name="wycats/jspec")
# Repository(full_name="defunkt/exception_logger")
# Repository(full_name="defunkt/ambition")
# Repository(full_name="technoweenie/restful-authentication")
# Repository(full_name="technoweenie/attachment_fu")
# Repository(full_name="caged/microsis")
# Repository(full_name="anotherjesse/s3")
# Repository(full_name="anotherjesse/taboo")
# Repository(full_name="anotherjesse/foxtracs")
# Repository(full_name="anotherjesse/fotomatic")
# Repository(full_name="mojombo/glowstick")
# Repository(full_name="defunkt/starling")
# Repository(full_name="wycats/merb-more")
# Repository(full_name="macournoyer/thin")
# Repository(full_name="jamesgolick/resource_controller")
# Repository(full_name="jamesgolick/markaby")
# ...

# %%
user = g.get_user()

# %%
user.login
# Out:
# 'arun728'

# %%
for repo in g.get_user().get_repos():
    print(repo.name)
# Out:
# Machine-Learning

# %%
with open("subject-scheme-prod - Copy.ditamap") as f:
    content = f.read()

# %%
# content

# %%
repo = g.get_repo("arun728/Machine-Learning")

# %%
contents = repo.get_contents("Subject Scheme Automation/subject-scheme-prod.ditamap")

# %%
contents.path
# Out:
# 'Subject Scheme Automation/subject-scheme-prod.ditamap'

# %%
repo.update_file(contents.path, "New commit", content, contents.sha, branch='main')
# Out:
# {'commit': Commit(sha="098e87ede83cf79ca947fed7de79621b2acbae1f"),
#  'content': ContentFile(path="Subject Scheme Automation/subject-scheme-prod.ditamap")}

# %%
help(repo.create_pull)
# Out:
# Help on method create_pull in module github.Repository:
#
# create_pull(*args, **kwds) method of github.Repository.Repository instance
#     :calls: `POST /repos/{owner}/{repo}/pulls <http://docs.github.com/en/rest/reference/pulls>`_
#     :param title: string
#     :param body: string
#     :param issue: :class:`github.Issue.Issue`
#     :param base: string
#     :param head: string
#     :param draft: bool
#     :param maintainer_can_modify: bool
#     :rtype: :class:`github.PullRequest.PullRequest`

# %%
src1 = 'C:\\Users\\akumar5\\Documents\\GitHub\\infoDev\\subject-scheme\\ditamap\\subject-scheme-prod.ditamap'
dst1 = 'C:\\Users\\akumar5\\Documents\\GitHub\\Machine-Learning\\Subject Scheme Automation'

# %%
src2 = 'C:\\Users\\akumar5\\Documents\\GitHub\\Machine-Learning\\Subject Scheme Automation\\subject-scheme-prod.ditamap'
dst2 = 'C:\\Users\\akumar5\\Documents\\GitHub\\infoDev\\subject-scheme\\ditamap'

# %%
shutil.move(src, dst)
