# %%
from github import Github
import os
from pprint import pprint

# %%
g = Github(login_or_token='01fcc64ef267686a4e9be00b8c0d4191650ecf3b',base_url='https://github-lvs.corpzone.internalzone.com/api/v3')

# %%
for u in g.get_repos():
    print(u)
# Out:
# Repository(full_name="ewuehler/PushAndFetch")
# Repository(full_name="ewuehler/PushAndFetchServer")
# Repository(full_name="sandbox/hackdays-ideas")
# Repository(full_name="sandbox/safari-extension")
# Repository(full_name="sandbox/DOMKEY")
# Repository(full_name="sandbox/go-kitn")
# Repository(full_name="sandbox/raspberry-tv")
# Repository(full_name="sandbox/tk-health-reports")
# Repository(full_name="sandbox/globe")
# Repository(full_name="sandbox/hackday2-ideas")
# Repository(full_name="sandbox/quackest")
# Repository(full_name="sandbox/buackest")
# Repository(full_name="sandbox/slick")
# Repository(full_name="sgrover/seth")
# Repository(full_name="sgrover/fpc")
# Repository(full_name="mhulse/sandbox")
# Repository(full_name="jmdacruz/confd-sandbox")
# Repository(full_name="emccoy/gtibo-puppet")
# Repository(full_name="emccoy/gtibo-puppet-old")
# Repository(full_name="SDuchesn/url-parser")
# Repository(full_name="SDuchesn/visible")
# Repository(full_name="SDuchesn/translations")
# ...

# %%
for repo in g.get_user().get_repos():
    print(repo.name)
# Out:
# 1-App_Android-POC
# 101
# 12C_SalesForce
# 16-cxd-android
# 16-cxd-desktop
# 16-cxd-ios
# 16-cxd-web-email
# 16-mktg
# 1AppSDK
# 3rdpartybin
# 56rtgdfdgfdgfgfd
# A2B
# AASDK
# aasdk-poc
# abbng
# AbhishekCodeTesting
# ABTDashboard
# AC3-ENGG-SPECS
# ac3-hubble
# ac3-sightings
# ac3-tools
# AC3_Tools_Automations
# access-point-addon
# accuracy
# ACE-Controller
# ACE-Tests
# acm
# acr
# AcrLoader
# AcrolinxReportConverter
# acronyms
# acs-migration
# ActivationWizardHost
# ActivationWizardHost-Package
# ActivationWizardStartUp
# ActivationWizardStartUp-Package
# ActivationWizardUI
# ActivationWizardUI-Package
# active-response-catalog-poc
# active-response-commons
# active-response-content-metamorph
# active-response-content-service-metamorph
# active-response-cxp
# active-response-epo-extensions
# active-response-epo-webapp
# active-response-integration
# active-response-kps
# active-response-query-parser
# active-response-remediation
# active-response-researchers-metamorph
# ...

# %%
user = g.get_user()

# %%
user.login
# Out:
# 'akumar5'

# %%
user.name
# Out:
# 'akumar5'

# %%
repo = g.get_repo("mcafee/infoDev")

# %%
repo.name
# Out:
# 'infoDev'

# %%
con = repo.get_contents("subject-scheme/ditamap/subject-scheme-prod.ditamap")

# %%
for c in con:
    print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-5870d5843a53> in <module>
# ----> 1 for c in con:
#       2     print(c)
#
# TypeError: 'ContentFile' object is not iterable

# %%
con.path
# Out:
# 'subject-scheme/ditamap/subject-scheme-prod.ditamap'

# %%
repo.update()
